# %%
import csv

# %%
county_list = []
with open('data/sample.csv', 'rU') as csvfile:
    reader = csv.DictReader(csvfile)
    for line in reader:
        county_list.append(line['county'])

# %%
county_list
# Out:
# ['CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'CLAY COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
#  'SUWANNEE COUNTY',
# ...

# %%
a = [1,2,3]
b = [4,5,6]

# %%
a.extend(b)

# %%
a
# Out:
# [1, 2, 3, [4, 5, 6], 4, 5, 6]
